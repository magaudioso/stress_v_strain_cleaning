# %%
import csv
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy.stats import linregress
from matplotlib import style
from matplotlib.pyplot import figure
figure(num=None, figsize = (20,30), dpi = 300)
import os
import seaborn as sns
sns.set()

# %% [markdown]
# # Make a master dataframe of all the 6 samples

# %% [markdown]
# ## Import all the csv's and make a df w/each sample as a header/column

# %%
df = pd.read_csv(r"E:\National Research Council of Canada\YadienkaCNTResults\new_plots\CNT_cummulative_output_array.csv", header=[0,1,2,3])

specimen_type = df.columns[0][0]
first_specimen = df.columns[0][1]
second_specimen = df.columns[24][1]
third_specimen = df.columns[48][1]
fourth_specimen = df.columns[72][1]
print(first_specimen, second_specimen, third_specimen, fourth_specimen)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-3-e4a2804f0ec2> in <module>
# ----> 1 df = pd.read_csv(r"E:\National Research Council of Canada\YadienkaCNTResults\new_plots\CNT_cummulative_output_array.csv", header=[0,1,2,3])
#       2
#       3 specimen_type = df.columns[0][0]
#       4 first_specimen = df.columns[0][1]
#       5 second_specimen = df.columns[24][1]
#
# ...

# %% [markdown]
# # PLOTS

# %% [markdown]
# ### Plots by Specimen

# %% [markdown]
# #### K28A-17 Dirty Plot

# %%
sample1_specs = {'Stress (N/mm)' : np.diff(df[specimen_type][first_specimen]['Sample 1']['Stress (N/mm)']), 'Strain (mm/mm)': np.diff(df[specimen_type][first_specimen]['Sample 1']['Strain (mm/mm)'])} 
a = pd.DataFrame(data=sample1_specs)
a = a[a[:] > -0.1].dropna()
b = a.index
df_1_1 = (df.truncate(after = b[-1]+2)).copy()
#Bad run(broke at the grip)
plt.plot(df_1_1[specimen_type][first_specimen]['Sample 1']['Strain (mm/mm)'], df_1_1[specimen_type][first_specimen]['Sample 1']['Stress (N/mm)'], color = 'red', marker = 'o', markersize = 2, label = first_specimen + ' Sample 1')

sample2_specs = {'Stress (N/mm)' : np.diff(df[specimen_type][first_specimen]['Sample 2']['Stress (N/mm)']), 'Strain (mm/mm)': np.diff(df[specimen_type][first_specimen]['Sample 2']['Strain (mm/mm)'])} 
a = pd.DataFrame(data=sample2_specs)
a = a[a[:] > -0.1].dropna()
b = a.index
df_1_2 = (df.truncate(after = b[-1]+2)).copy()
#Good run (broke in the gauge)
plt.plot(df_1_2[specimen_type][first_specimen]['Sample 2']['Strain (mm/mm)'], df_1_2[specimen_type][first_specimen]['Sample 2']['Stress (N/mm)'], color = 'orange', marker = 'o', markersize = 2, label = first_specimen + ' Sample 2')

sample3_specs = {'Stress (N/mm)' : np.diff(df[specimen_type][first_specimen]['Sample 3']['Stress (N/mm)']), 'Strain (mm/mm)': np.diff(df[specimen_type][first_specimen]['Sample 3']['Strain (mm/mm)'])} 
a = pd.DataFrame(data=sample3_specs)
a = a[a[:] > -0.1].dropna()
b = a.index
df_1_3 = (df.truncate(after = b[-1]+2)).copy()
#Bad run (broke in the grip)
plt.plot(df_1_3[specimen_type][first_specimen]['Sample 3']['Strain (mm/mm)'], df_1_3[specimen_type][first_specimen]['Sample 3']['Stress (N/mm)'], color = 'goldenrod' ,marker = 'o', markersize = 2, label = first_specimen + ' Sample 3')

sample4_specs = {'Stress (N/mm)' : np.diff(df[specimen_type][first_specimen]['Sample 4']['Stress (N/mm)']), 'Strain (mm/mm)': np.diff(df[specimen_type][first_specimen]['Sample 4']['Strain (mm/mm)'])} 
a = pd.DataFrame(data=sample4_specs)
a = a[a[:] > -0.1].dropna()
b = a.index
df_1_4 = (df.truncate(after = b[-1]+2)).copy()
#Bad run (broke in the grip)
plt.plot(df_1_4[specimen_type][first_specimen]['Sample 4']['Strain (mm/mm)'], df_1_4[specimen_type][first_specimen]['Sample 4']['Stress (N/mm)'], color = 'lime', marker = 'o', markersize = 2, label = first_specimen + ' Sample 4')

sample5_specs = {'Stress (N/mm)' : np.diff(df[specimen_type][first_specimen]['Sample 5']['Stress (N/mm)']), 'Strain (mm/mm)': np.diff(df[specimen_type][first_specimen]['Sample 5']['Strain (mm/mm)'])} 
a = pd.DataFrame(data=sample5_specs)
a = a[a[:] > -0.1].dropna()
b = a.index
df_1_5 = (df.truncate(after = b[-1]+2)).copy()
#good run (broke in the gauge)
plt.plot(df_1_5[specimen_type][first_specimen]['Sample 5']['Strain (mm/mm)'], df_1_5[specimen_type][first_specimen]['Sample 5']['Stress (N/mm)'], color = 'blue', marker = 'o', markersize = 2, label = first_specimen + ' Sample 5')

sample6_specs = {'Stress (N/mm)' : np.diff(df[specimen_type][first_specimen]['Sample 6']['Stress (N/mm)']), 'Strain (mm/mm)': np.diff(df[specimen_type][first_specimen]['Sample 6']['Strain (mm/mm)'])} 
a = pd.DataFrame(data=sample6_specs)
a = a[a[:] > -0.1].dropna()
b = a.index
df_1_6 = (df.truncate(after = b[-1]+2)).copy()
#okay run (broke in the gauge barely)
plt.plot(df_1_6[specimen_type][first_specimen]['Sample 6']['Strain (mm/mm)'], df_1_6[specimen_type][first_specimen]['Sample 6']['Stress (N/mm)'], color = 'purple', marker = 'o', markersize = 2, label = first_specimen +' Sample 6')

plt.title(specimen_type + ' : ' + first_specimen + ' Samples 1-6' + ' (Dirty)')
plt.ylabel('Stress (MPa)')
plt.xlabel('Strain (mm/mm)')
plt.legend(loc=10, bbox_to_anchor=(1.3,0.5))
plt.savefig(r'E:\National Research Council of Canada\YadienkaCNTResults\new_plots\K28A-17\cummulative_stress_v_strain_dirty.png', dpi = 300, bbox_inches ='tight')
plt.show()

# %% [markdown]
# #### K28A-17 Cleaned

# %%
sample1_specs = {'Stress (N/mm)' : np.diff(df[specimen_type][first_specimen]['Sample 1']['Stress (N/mm)']), 'Strain (mm/mm)': np.diff(df[specimen_type][first_specimen]['Sample 1']['Strain (mm/mm)'])} 
a = pd.DataFrame(data=sample1_specs)
a = a[a[:] > -0.1].dropna()
b = a.index
df_1_1 = (df.truncate(after = b[-1]+2)).copy()
#Bad run(broke at the grip)
#plt.plot(df_1_1[specimen_type][first_specimen]['Sample 1']['Strain (mm/mm)'], df_1_1[specimen_type][first_specimen]['Sample 1']['Stress (N/mm)'], color = 'red', marker = 'o', markersize = 2, label = first_specimen + ' Sample 1')

sample2_specs = {'Stress (N/mm)' : np.diff(df[specimen_type][first_specimen]['Sample 2']['Stress (N/mm)']), 'Strain (mm/mm)': np.diff(df[specimen_type][first_specimen]['Sample 2']['Strain (mm/mm)'])} 
a = pd.DataFrame(data=sample2_specs)
a = a[a[:] > -0.1].dropna()
b = a.index
df_1_2 = (df.truncate(after = b[-1]+2)).copy()
#Good run (broke in the gauge)
plt.plot(df_1_2[specimen_type][first_specimen]['Sample 2']['Strain (mm/mm)'], df_1_2[specimen_type][first_specimen]['Sample 2']['Stress (N/mm)'], color = 'orange', marker = 'o', markersize = 2, label = first_specimen + ' Sample 2')

sample3_specs = {'Stress (N/mm)' : np.diff(df[specimen_type][first_specimen]['Sample 3']['Stress (N/mm)']), 'Strain (mm/mm)': np.diff(df[specimen_type][first_specimen]['Sample 3']['Strain (mm/mm)'])} 
a = pd.DataFrame(data=sample3_specs)
a = a[a[:] > -0.1].dropna()
b = a.index
df_1_3 = (df.truncate(after = b[-1]+2)).copy()
#Bad run (broke in the grip)
#plt.plot(df_1_3[specimen_type][first_specimen]['Sample 3']['Strain (mm/mm)'], df_1_3[specimen_type][first_specimen]['Sample 3']['Stress (N/mm)'], color = 'goldenrod' ,marker = 'o', markersize = 2, label = first_specimen + ' Sample 3')

sample4_specs = {'Stress (N/mm)' : np.diff(df[specimen_type][first_specimen]['Sample 4']['Stress (N/mm)']), 'Strain (mm/mm)': np.diff(df[specimen_type][first_specimen]['Sample 4']['Strain (mm/mm)'])} 
a = pd.DataFrame(data=sample4_specs)
a = a[a[:] > -0.1].dropna()
b = a.index
df_1_4 = (df.truncate(after = b[-1]+2)).copy()
#Bad run (broke in the grip)
#plt.plot(df_1_4[specimen_type][first_specimen]['Sample 4']['Strain (mm/mm)'], df_1_4[specimen_type][first_specimen]['Sample 4']['Stress (N/mm)'], color = 'lime', marker = 'o', markersize = 2, label = first_specimen + ' Sample 4')

sample5_specs = {'Stress (N/mm)' : np.diff(df[specimen_type][first_specimen]['Sample 5']['Stress (N/mm)']), 'Strain (mm/mm)': np.diff(df[specimen_type][first_specimen]['Sample 5']['Strain (mm/mm)'])} 
a = pd.DataFrame(data=sample5_specs)
a = a[a[:] > -0.1].dropna()
b = a.index
df_1_5 = (df.truncate(after = b[-1]+2)).copy()
#good run (broke in the gauge)
plt.plot(df_1_5[specimen_type][first_specimen]['Sample 5']['Strain (mm/mm)'], df_1_5[specimen_type][first_specimen]['Sample 5']['Stress (N/mm)'], color = 'blue', marker = 'o', markersize = 2, label = first_specimen + ' Sample 5')

sample6_specs = {'Stress (N/mm)' : np.diff(df[specimen_type][first_specimen]['Sample 6']['Stress (N/mm)']), 'Strain (mm/mm)': np.diff(df[specimen_type][first_specimen]['Sample 6']['Strain (mm/mm)'])} 
a = pd.DataFrame(data=sample6_specs)
a = a[a[:] > -0.1].dropna()
b = a.index
df_1_6 = (df.truncate(after = b[-1]+2)).copy()
#okay run (broke in the gauge barely)
plt.plot(df_1_6[specimen_type][first_specimen]['Sample 6']['Strain (mm/mm)'], df_1_6[specimen_type][first_specimen]['Sample 6']['Stress (N/mm)'], color = 'purple', marker = 'o', markersize = 2, label = first_specimen +' Sample 6')



plt.title(specimen_type + ' : ' + first_specimen  + ' (cleaned)')
plt.ylabel('Stress (MPa)')
plt.xlabel('Strain (mm/mm)')
plt.legend(loc=10, bbox_to_anchor=(1.3,0.5))
plt.savefig(r'E:\National Research Council of Canada\YadienkaCNTResults\new_plots\K28A-17\cummulative_stress_v_strain_clean.png', dpi = 300,  bbox_inches ='tight')
plt.show()

# %% [markdown]
# #### K28A-35 Dirty

# %%
sample1_specs = {'Stress (N/mm)' : np.diff(df[specimen_type][second_specimen]['Sample 1']['Stress (N/mm)']), 'Strain (mm/mm)': np.diff(df[specimen_type][second_specimen]['Sample 1']['Strain (mm/mm)'])} 
a = pd.DataFrame(data=sample1_specs)
a = a[a[:] > -0.1].dropna()
b = a.index
df_2_1 = (df.truncate(after = b[-1]+2)).copy()
#good run
plt.plot(df_2_1[specimen_type][second_specimen]['Sample 1']['Strain (mm/mm)'], df_2_1[specimen_type][second_specimen]['Sample 1']['Stress (N/mm)'], color = 'red', marker = 'o', markersize = 2, label = second_specimen + ' Sample 1')

sample2_specs = {'Stress (N/mm)' : np.diff(df[specimen_type][second_specimen]['Sample 2']['Stress (N/mm)']), 'Strain (mm/mm)': np.diff(df[specimen_type][second_specimen]['Sample 2']['Strain (mm/mm)'])} 
a = pd.DataFrame(data=sample2_specs)
a = a[a[:] > -0.1].dropna()
b = a.index
df_2_2 = (df.truncate(after = b[-1]+2)).copy()
#okay run (broke in the gauge)
plt.plot(df_2_2[specimen_type][second_specimen]['Sample 2']['Strain (mm/mm)'], df_2_2[specimen_type][second_specimen]['Sample 2']['Stress (N/mm)'], color = 'orange', marker = 'o', markersize = 2, label = second_specimen + ' Sample 2')

sample3_specs = {'Stress (N/mm)' : np.diff(df[specimen_type][second_specimen]['Sample 3']['Stress (N/mm)']), 'Strain (mm/mm)': np.diff(df[specimen_type][second_specimen]['Sample 3']['Strain (mm/mm)'])} 
a = pd.DataFrame(data=sample3_specs)
a = a[a[:] > -0.1].dropna()
b = a.index
df_2_3 = (df.truncate(after = b[-1]+2)).copy()
#good run
plt.plot(df_2_3[specimen_type][second_specimen]['Sample 3']['Strain (mm/mm)'], df_2_3[specimen_type][second_specimen]['Sample 3']['Stress (N/mm)'], color = 'goldenrod' ,marker = 'o', markersize = 2, label = second_specimen + ' Sample 3')

sample4_specs = {'Stress (N/mm)' : np.diff(df[specimen_type][second_specimen]['Sample 4']['Stress (N/mm)']), 'Strain (mm/mm)': np.diff(df[specimen_type][second_specimen]['Sample 4']['Strain (mm/mm)'])} 
a = pd.DataFrame(data=sample4_specs)
a = a[a[:] > -0.1].dropna()
b = a.index
df_2_4 = (df.truncate(after = b[-1]+2)).copy()
#okay run 
plt.plot(df_2_4[specimen_type][second_specimen]['Sample 4']['Strain (mm/mm)'], df_2_4[specimen_type][second_specimen]['Sample 4']['Stress (N/mm)'], color = 'lime', marker = 'o', markersize = 2, label = second_specimen + ' Sample 4')

sample5_specs = {'Stress (N/mm)' : np.diff(df[specimen_type][second_specimen]['Sample 5']['Stress (N/mm)']), 'Strain (mm/mm)': np.diff(df[specimen_type][second_specimen]['Sample 5']['Strain (mm/mm)'])} 
a = pd.DataFrame(data=sample5_specs)
a = a[a[:] > -0.1].dropna()
b = a.index
df_2_5 = (df.truncate(after = b[-1]+1)).copy()
#bad run (broke in the grip)
plt.plot(df_2_5[specimen_type][second_specimen]['Sample 5']['Strain (mm/mm)'], df_2_5[specimen_type][second_specimen]['Sample 5']['Stress (N/mm)'], color = 'blue', marker = 'o', markersize = 2, label = second_specimen + ' Sample 5')

sample6_specs = {'Stress (N/mm)' : np.diff(df[specimen_type][second_specimen]['Sample 6']['Stress (N/mm)']), 'Strain (mm/mm)': np.diff(df[specimen_type][second_specimen]['Sample 6']['Strain (mm/mm)'])} 
a = pd.DataFrame(data=sample6_specs)
a = a[a[:] > -0.1].dropna()
b = a.index
df_2_6 = (df.truncate(after = b[-1]+2)).copy()
#bad run (broke in the grip)
plt.plot(df_2_6[specimen_type][second_specimen]['Sample 6']['Strain (mm/mm)'], df_2_6[specimen_type][second_specimen]['Sample 6']['Stress (N/mm)'], color = 'purple', marker = 'o', markersize = 2, label = second_specimen +' Sample 6')



plt.title(specimen_type + ' : ' + second_specimen  + ' (Dirty)')
plt.ylabel('Stress (MPa)')
plt.xlabel('Strain (mm/mm)')
plt.legend(loc=10, bbox_to_anchor=(1.3,0.5))
plt.savefig(r'E:\National Research Council of Canada\YadienkaCNTResults\new_plots\K28A-35\cummulative_stress_v_strain_dirty.png', dpi = 300,  bbox_inches ='tight')
plt.show()

# %% [markdown]
# ## K28A-35 clean

# %%
sample1_specs = {'Stress (N/mm)' : np.diff(df[specimen_type][second_specimen]['Sample 1']['Stress (N/mm)']), 'Strain (mm/mm)': np.diff(df[specimen_type][second_specimen]['Sample 1']['Strain (mm/mm)'])} 
a = pd.DataFrame(data=sample1_specs)
a = a[a[:] > -0.1].dropna()
b = a.index
df_2_1 = (df.truncate(after = b[-1]+2)).copy()
#good run
plt.plot(df_2_1[specimen_type][second_specimen]['Sample 1']['Strain (mm/mm)'], df_2_1[specimen_type][second_specimen]['Sample 1']['Stress (N/mm)'], color = 'red', marker = 'o', markersize = 2, label = second_specimen + ' Sample 1')

sample2_specs = {'Stress (N/mm)' : np.diff(df[specimen_type][second_specimen]['Sample 2']['Stress (N/mm)']), 'Strain (mm/mm)': np.diff(df[specimen_type][second_specimen]['Sample 2']['Strain (mm/mm)'])} 
a = pd.DataFrame(data=sample2_specs)
a = a[a[:] > -0.1].dropna()
b = a.index
df_2_2 = (df.truncate(after = b[-1]+2)).copy()
#okay run (broke in the gauge)
plt.plot(df_2_2[specimen_type][second_specimen]['Sample 2']['Strain (mm/mm)'], df_2_2[specimen_type][second_specimen]['Sample 2']['Stress (N/mm)'], color = 'orange', marker = 'o', markersize = 2, label = second_specimen + ' Sample 2')

sample3_specs = {'Stress (N/mm)' : np.diff(df[specimen_type][second_specimen]['Sample 3']['Stress (N/mm)']), 'Strain (mm/mm)': np.diff(df[specimen_type][second_specimen]['Sample 3']['Strain (mm/mm)'])} 
a = pd.DataFrame(data=sample3_specs)
a = a[a[:] > -0.1].dropna()
b = a.index
df_2_3 = (df.truncate(after = b[-1]+2)).copy()
#good run
plt.plot(df_2_3[specimen_type][second_specimen]['Sample 3']['Strain (mm/mm)'], df_2_3[specimen_type][second_specimen]['Sample 3']['Stress (N/mm)'], color = 'goldenrod' ,marker = 'o', markersize = 2, label = second_specimen + ' Sample 3')

sample4_specs = {'Stress (N/mm)' : np.diff(df[specimen_type][second_specimen]['Sample 4']['Stress (N/mm)']), 'Strain (mm/mm)': np.diff(df[specimen_type][second_specimen]['Sample 4']['Strain (mm/mm)'])} 
a = pd.DataFrame(data=sample4_specs)
a = a[a[:] > -0.1].dropna()
b = a.index
df_2_4 = (df.truncate(after = b[-1]+2)).copy()
#okay run 
plt.plot(df_2_4[specimen_type][second_specimen]['Sample 4']['Strain (mm/mm)'], df_2_4[specimen_type][second_specimen]['Sample 4']['Stress (N/mm)'], color = 'lime', marker = 'o', markersize = 2, label = second_specimen + ' Sample 4')

# sample5_specs = {'Stress (N/mm)' : np.diff(df[specimen_type][second_specimen]['Sample 5']['Stress (N/mm)']), 'Strain (mm/mm)': np.diff(df[specimen_type][second_specimen]['Sample 5']['Strain (mm/mm)'])} 
# a = pd.DataFrame(data=sample5_specs)
# a = a[a[:] > -0.1].dropna()
# b = a.index
# df_2_5 = (df.truncate(after = b[-1]+1)).copy()
# #bad run (broke in the grip)
# plt.plot(df_2_5[specimen_type][second_specimen]['Sample 5']['Strain (mm/mm)'], df_2_5[specimen_type][second_specimen]['Sample 5']['Stress (N/mm)'], color = 'blue', marker = 'o', markersize = 2, label = second_specimen + ' Sample 5')

# sample6_specs = {'Stress (N/mm)' : np.diff(df[specimen_type][second_specimen]['Sample 6']['Stress (N/mm)']), 'Strain (mm/mm)': np.diff(df[specimen_type][second_specimen]['Sample 6']['Strain (mm/mm)'])} 
# a = pd.DataFrame(data=sample6_specs)
# a = a[a[:] > -0.1].dropna()
# b = a.index
# df_2_6 = (df.truncate(after = b[-1]+2)).copy()
# #bad run (broke in the grip)
# plt.plot(df_2_6[specimen_type][second_specimen]['Sample 6']['Strain (mm/mm)'], df_2_6[specimen_type][second_specimen]['Sample 6']['Stress (N/mm)'], color = 'purple', marker = 'o', markersize = 2, label = second_specimen +' Sample 6')



plt.title(specimen_type + ' : ' + second_specimen  + ' (cleaned)')
plt.ylabel('Stress (MPa)')
plt.xlabel('Strain (mm/mm)')
plt.legend(loc=10, bbox_to_anchor=(1.3,0.5))
plt.savefig(r'E:\National Research Council of Canada\YadienkaCNTResults\new_plots\K28A-35\cummulative_stress_v_strain_clean.png',  bbox_inches ='tight', dpi = 300)
plt.show()

# %% [markdown]
# ## K28B-17

# %%
sample1_specs = {'Stress (N/mm)' : np.diff(df[specimen_type][third_specimen]['Sample 1']['Stress (N/mm)']), 'Strain (mm/mm)': np.diff(df[specimen_type][third_specimen]['Sample 1']['Strain (mm/mm)'])} 
a = pd.DataFrame(data=sample1_specs)
b = a.index
df_2_1 = (df.truncate(after = b[-1]+2)).copy()
#good run
plt.plot(df_2_1[specimen_type][third_specimen]['Sample 1']['Strain (mm/mm)'], df_2_1[specimen_type][third_specimen]['Sample 1']['Stress (N/mm)'], color = 'red', marker = 'o', markersize = 2, label = third_specimen + ' Sample 1')

sample2_specs = {'Stress (N/mm)' : np.diff(df[specimen_type][third_specimen]['Sample 2']['Stress (N/mm)']), 'Strain (mm/mm)': np.diff(df[specimen_type][third_specimen]['Sample 2']['Strain (mm/mm)'])} 
a = pd.DataFrame(data=sample2_specs)
a = a[a[:] > -0.1].dropna()
b = a.index
df_2_2 = (df.truncate(after = b[-1]+2)).copy()
#good run (broke in the gauge)
plt.plot(df_2_2[specimen_type][third_specimen]['Sample 2']['Strain (mm/mm)'], df_2_2[specimen_type][third_specimen]['Sample 2']['Stress (N/mm)'], color = 'orange', marker = 'o', markersize = 2, label = third_specimen + ' Sample 2')

sample3_specs = {'Stress (N/mm)' : np.diff(df[specimen_type][third_specimen]['Sample 3']['Stress (N/mm)']), 'Strain (mm/mm)': np.diff(df[specimen_type][third_specimen]['Sample 3']['Strain (mm/mm)'])} 
a = pd.DataFrame(data=sample3_specs)
a = a[a[:] > -0.1].dropna()
b = a.index
df_2_3 = (df.truncate(after = b[-1]+2)).copy()
#bad run
plt.plot(df_2_3[specimen_type][third_specimen]['Sample 3']['Strain (mm/mm)'], df_2_3[specimen_type][third_specimen]['Sample 3']['Stress (N/mm)'], color = 'goldenrod' ,marker = 'o', markersize = 2, label = third_specimen + ' Sample 3')

sample4_specs = {'Stress (N/mm)' : np.diff(df[specimen_type][third_specimen]['Sample 4']['Stress (N/mm)']), 'Strain (mm/mm)': np.diff(df[specimen_type][third_specimen]['Sample 4']['Strain (mm/mm)'])} 
a = pd.DataFrame(data=sample4_specs)
a = a[a[:] > -0.1].dropna()
b = a.index
df_2_4 = (df.truncate(after = b[-1]+2)).copy()
#bad run 
plt.plot(df_2_4[specimen_type][third_specimen]['Sample 4']['Strain (mm/mm)'], df_2_4[specimen_type][third_specimen]['Sample 4']['Stress (N/mm)'], color = 'lime', marker = 'o', markersize = 2, label = third_specimen + ' Sample 4')

sample5_specs = {'Stress (N/mm)' : np.diff(df[specimen_type][third_specimen]['Sample 5']['Stress (N/mm)']), 'Strain (mm/mm)': np.diff(df[specimen_type][third_specimen]['Sample 5']['Strain (mm/mm)'])} 
a = pd.DataFrame(data=sample5_specs)
a = a[a[:] > -0.1].dropna()
b = a.index
df_2_5 = (df.truncate(after = b[-1]+1)).copy()
#bad run (broke in the grip)
plt.plot(df_2_5[specimen_type][third_specimen]['Sample 5']['Strain (mm/mm)'], df_2_5[specimen_type][third_specimen]['Sample 5']['Stress (N/mm)'], color = 'blue', marker = 'o', markersize = 2, label = third_specimen + ' Sample 5')

sample6_specs = {'Stress (N/mm)' : np.diff(df[specimen_type][third_specimen]['Sample 6']['Stress (N/mm)']), 'Strain (mm/mm)': np.diff(df[specimen_type][third_specimen]['Sample 6']['Strain (mm/mm)'])} 
a = pd.DataFrame(data=sample6_specs)
a = a[a[:] > -0.1].dropna()
b = a.index
df_2_6 = (df.truncate(after = b[-1]+2)).copy()
#bad run (broke in the grip)
plt.plot(df_2_6[specimen_type][third_specimen]['Sample 6']['Strain (mm/mm)'], df_2_6[specimen_type][third_specimen]['Sample 6']['Stress (N/mm)'], color = 'purple', marker = 'o', markersize = 2, label = third_specimen +' Sample 6')



plt.title(specimen_type + ' : ' + third_specimen  + ' (dirty)')
plt.ylabel('Stress (MPa)')
plt.xlabel('Strain (mm/mm)')
plt.legend(loc=10, bbox_to_anchor=(1.3,0.5))
plt.savefig(r'E:\National Research Council of Canada\YadienkaCNTResults\new_plots\K28B-17\cummulative_stress_v_strain_dirty.png', dpi = 300,  bbox_inches ='tight')
plt.show()

# %%
sample1_specs = {'Stress (N/mm)' : np.diff(df[specimen_type][third_specimen]['Sample 1']['Stress (N/mm)']), 'Strain (mm/mm)': np.diff(df[specimen_type][third_specimen]['Sample 1']['Strain (mm/mm)'])} 
a = pd.DataFrame(data=sample1_specs)
a = a[a[:] > -0.1].dropna()
b = a.index
df_2_1 = (df.truncate(after = b[-1]+2)).copy()
#good run
plt.plot(df_2_1[specimen_type][third_specimen]['Sample 1']['Strain (mm/mm)'], df_2_1[specimen_type][third_specimen]['Sample 1']['Stress (N/mm)'], color = 'red', marker = 'o', markersize = 2, label = third_specimen + ' Sample 1')

sample2_specs = {'Stress (N/mm)' : np.diff(df[specimen_type][third_specimen]['Sample 2']['Stress (N/mm)']), 'Strain (mm/mm)': np.diff(df[specimen_type][third_specimen]['Sample 2']['Strain (mm/mm)'])} 
a = pd.DataFrame(data=sample2_specs)
a = a[a[:] > -0.1].dropna()
b = a.index
df_2_2 = (df.truncate(after = b[-1]+2)).copy()
#good run (broke in the gauge)
plt.plot(df_2_2[specimen_type][third_specimen]['Sample 2']['Strain (mm/mm)'], df_2_2[specimen_type][third_specimen]['Sample 2']['Stress (N/mm)'], color = 'orange', marker = 'o', markersize = 2, label = third_specimen + ' Sample 2')

# sample3_specs = {'Stress (N/mm)' : np.diff(df[specimen_type][third_specimen]['Sample 3']['Stress (N/mm)']), 'Strain (mm/mm)': np.diff(df[specimen_type][third_specimen]['Sample 3']['Strain (mm/mm)'])} 
# a = pd.DataFrame(data=sample3_specs)
# a = a[a[:] > -0.1].dropna()
# b = a.index
# df_2_3 = (df.truncate(after = b[-1]+2)).copy()
# #bad run
# plt.plot(df_2_3[specimen_type][third_specimen]['Sample 3']['Strain (mm/mm)'], df_2_3[specimen_type][third_specimen]['Sample 3']['Stress (N/mm)'], color = 'goldenrod' ,marker = 'o', markersize = 2, label = third_specimen + ' Sample 3')

# sample4_specs = {'Stress (N/mm)' : np.diff(df[specimen_type][third_specimen]['Sample 4']['Stress (N/mm)']), 'Strain (mm/mm)': np.diff(df[specimen_type][third_specimen]['Sample 4']['Strain (mm/mm)'])} 
# a = pd.DataFrame(data=sample4_specs)
# a = a[a[:] > -0.1].dropna()
# b = a.index
# df_2_4 = (df.truncate(after = b[-1]+2)).copy()
# #bad run 
# plt.plot(df_2_4[specimen_type][third_specimen]['Sample 4']['Strain (mm/mm)'], df_2_4[specimen_type][third_specimen]['Sample 4']['Stress (N/mm)'], color = 'lime', marker = 'o', markersize = 2, label = third_specimen + ' Sample 4')

# sample5_specs = {'Stress (N/mm)' : np.diff(df[specimen_type][third_specimen]['Sample 5']['Stress (N/mm)']), 'Strain (mm/mm)': np.diff(df[specimen_type][third_specimen]['Sample 5']['Strain (mm/mm)'])} 
# a = pd.DataFrame(data=sample5_specs)
# a = a[a[:] > -0.1].dropna()
# b = a.index
# df_2_5 = (df.truncate(after = b[-1]+1)).copy()
# #bad run (broke in the grip)
# plt.plot(df_2_5[specimen_type][third_specimen]['Sample 5']['Strain (mm/mm)'], df_2_5[specimen_type][third_specimen]['Sample 5']['Stress (N/mm)'], color = 'blue', marker = 'o', markersize = 2, label = third_specimen + ' Sample 5')

# sample6_specs = {'Stress (N/mm)' : np.diff(df[specimen_type][third_specimen]['Sample 6']['Stress (N/mm)']), 'Strain (mm/mm)': np.diff(df[specimen_type][third_specimen]['Sample 6']['Strain (mm/mm)'])} 
# a = pd.DataFrame(data=sample6_specs)
# a = a[a[:] > -0.1].dropna()
# b = a.index
# df_2_6 = (df.truncate(after = b[-1]+2)).copy()
# #bad run (broke in the grip)
# plt.plot(df_2_6[specimen_type][third_specimen]['Sample 6']['Strain (mm/mm)'], df_2_6[specimen_type][third_specimen]['Sample 6']['Stress (N/mm)'], color = 'purple', marker = 'o', markersize = 2, label = third_specimen +' Sample 6')



plt.title(specimen_type + ' : ' + third_specimen  + ' (cleaned)')
plt.ylabel('Stress (MPa)')
plt.xlabel('Strain (mm/mm)')
plt.legend(loc=10, bbox_to_anchor=(1.3,0.5))
plt.savefig(r'E:\National Research Council of Canada\YadienkaCNTResults\new_plots\K28B-17\cummulative_stress_v_strain_clean.png', dpi = 300,  bbox_inches ='tight')
plt.show()

# %% [markdown]
# ### K28B-26

# %%
sample1_specs = {'Stress (N/mm)' : np.diff(df[specimen_type][fourth_specimen]['Sample 1']['Stress (N/mm)']), 'Strain (mm/mm)': np.diff(df[specimen_type][fourth_specimen]['Sample 1']['Strain (mm/mm)'])} 
a = pd.DataFrame(data=sample1_specs)
a = a[a[:] > -0.1].dropna()
b = a.index
df_2_1 = (df.truncate(after = b[-1]+2)).copy()
#good run
plt.plot(df_2_1[specimen_type][fourth_specimen]['Sample 1']['Strain (mm/mm)'], df_2_1[specimen_type][fourth_specimen]['Sample 1']['Stress (N/mm)'], color = 'red', marker = 'o', markersize = 2, label = fourth_specimen + ' Sample 1')

sample2_specs = {'Stress (N/mm)' : np.diff(df[specimen_type][fourth_specimen]['Sample 2']['Stress (N/mm)']), 'Strain (mm/mm)': np.diff(df[specimen_type][fourth_specimen]['Sample 2']['Strain (mm/mm)'])} 
a = pd.DataFrame(data=sample2_specs)
a = a[a[:] > -0.1].dropna()
b = a.index
df_2_2 = (df.truncate(after = b[-1]+2)).copy()
#good run (broke in the gauge)
plt.plot(df_2_2[specimen_type][fourth_specimen]['Sample 2']['Strain (mm/mm)'], df_2_2[specimen_type][fourth_specimen]['Sample 2']['Stress (N/mm)'], color = 'orange', marker = 'o', markersize = 2, label = fourth_specimen + ' Sample 2')

sample3_specs = {'Stress (N/mm)' : np.diff(df[specimen_type][fourth_specimen]['Sample 3']['Stress (N/mm)']), 'Strain (mm/mm)': np.diff(df[specimen_type][fourth_specimen]['Sample 3']['Strain (mm/mm)'])} 
a = pd.DataFrame(data=sample3_specs)
a = a[a[:] > -0.1].dropna()
b = a.index
df_2_3 = (df.truncate(after = b[-1]+2)).copy()
#bad run
plt.plot(df_2_3[specimen_type][fourth_specimen]['Sample 3']['Strain (mm/mm)'], df_2_3[specimen_type][fourth_specimen]['Sample 3']['Stress (N/mm)'], color = 'goldenrod' ,marker = 'o', markersize = 2, label = fourth_specimen + ' Sample 3')

sample4_specs = {'Stress (N/mm)' : np.diff(df[specimen_type][fourth_specimen]['Sample 4']['Stress (N/mm)']), 'Strain (mm/mm)': np.diff(df[specimen_type][fourth_specimen]['Sample 4']['Strain (mm/mm)'])} 
a = pd.DataFrame(data=sample4_specs)
a = a[a[:] > -0.1].dropna()
b = a.index
df_2_4 = (df.truncate(after = b[-1]-6)).copy()
#bad run 
plt.plot(df_2_4[specimen_type][fourth_specimen]['Sample 4']['Strain (mm/mm)'], df_2_4[specimen_type][fourth_specimen]['Sample 4']['Stress (N/mm)'], color = 'lime', marker = 'o', markersize = 2, label = fourth_specimen + ' Sample 4')

sample5_specs = {'Stress (N/mm)' : np.diff(df[specimen_type][fourth_specimen]['Sample 5']['Stress (N/mm)']), 'Strain (mm/mm)': np.diff(df[specimen_type][fourth_specimen]['Sample 5']['Strain (mm/mm)'])} 
a = pd.DataFrame(data=sample5_specs)
a = a[a[:] > -0.1].dropna()
b = a.index
df_2_5 = (df.truncate(after = b[-1]+2)).copy()
#bad run (broke in the grip)
plt.plot(df_2_5[specimen_type][fourth_specimen]['Sample 5']['Strain (mm/mm)'], df_2_5[specimen_type][fourth_specimen]['Sample 5']['Stress (N/mm)'], color = 'blue', marker = 'o', markersize = 2, label = fourth_specimen + ' Sample 5')

sample6_specs = {'Stress (N/mm)' : np.diff(df[specimen_type][fourth_specimen]['Sample 6']['Stress (N/mm)']), 'Strain (mm/mm)': np.diff(df[specimen_type][fourth_specimen]['Sample 6']['Strain (mm/mm)'])} 
a = pd.DataFrame(data=sample6_specs)
a = a[a[:] > -0.1].dropna()
b = a.index
df_2_6 = (df.truncate(after = b[-1]-4)).copy()
#bad run (broke in the grip)
plt.plot(df_2_6[specimen_type][fourth_specimen]['Sample 6']['Strain (mm/mm)'], df_2_6[specimen_type][fourth_specimen]['Sample 6']['Stress (N/mm)'], color = 'purple', marker = 'o', markersize = 2, label = third_specimen +' Sample 6')



plt.title(specimen_type + ' : ' + fourth_specimen  + ' (dirty)')
plt.ylabel('Stress (MPa)')
plt.xlabel('Strain (mm/mm)')
plt.legend(loc=10, bbox_to_anchor=(1.3,0.5))
plt.savefig(r'E:\National Research Council of Canada\YadienkaCNTResults\new_plots\K28B-26\cummulative_stress_v_strain_dirty.png', dpi = 300,  bbox_inches ='tight')
plt.show()

# %% [markdown]
# ## Cleaned

# %%
# sample1_specs = {'Stress (N/mm)' : np.diff(df[specimen_type][fourth_specimen]['Sample 1']['Stress (N/mm)']), 'Strain (mm/mm)': np.diff(df[specimen_type][fourth_specimen]['Sample 1']['Strain (mm/mm)'])} 
# a = pd.DataFrame(data=sample1_specs)
# a = a[a[:] > -0.1].dropna()
# b = a.index
# df_2_1 = (df.truncate(after = b[-1]+2)).copy()
# #bad run
# plt.plot(df_2_1[specimen_type][fourth_specimen]['Sample 1']['Strain (mm/mm)'], df_2_1[specimen_type][fourth_specimen]['Sample 1']['Stress (N/mm)'], color = 'red', marker = 'o', markersize = 2, label = fourth_specimen + ' Sample 1')

sample2_specs = {'Stress (N/mm)' : np.diff(df[specimen_type][fourth_specimen]['Sample 2']['Stress (N/mm)']), 'Strain (mm/mm)': np.diff(df[specimen_type][fourth_specimen]['Sample 2']['Strain (mm/mm)'])} 
a = pd.DataFrame(data=sample2_specs)
a = a[a[:] > -0.1].dropna()
b = a.index
df_2_2 = (df.truncate(after = b[-1]+2)).copy()
#good run (broke in the gauge)
plt.plot(df_2_2[specimen_type][fourth_specimen]['Sample 2']['Strain (mm/mm)'], df_2_2[specimen_type][fourth_specimen]['Sample 2']['Stress (N/mm)'], color = 'orange', marker = 'o', markersize = 2, label = fourth_specimen + ' Sample 2')

sample3_specs = {'Stress (N/mm)' : np.diff(df[specimen_type][fourth_specimen]['Sample 3']['Stress (N/mm)']), 'Strain (mm/mm)': np.diff(df[specimen_type][fourth_specimen]['Sample 3']['Strain (mm/mm)'])} 
a = pd.DataFrame(data=sample3_specs)
a = a[a[:] > -0.1].dropna()
b = a.index
df_2_3 = (df.truncate(after = b[-1]+2)).copy()
#okay run
plt.plot(df_2_3[specimen_type][fourth_specimen]['Sample 3']['Strain (mm/mm)'], df_2_3[specimen_type][fourth_specimen]['Sample 3']['Stress (N/mm)'], color = 'goldenrod' ,marker = 'o', markersize = 2, label = fourth_specimen + ' Sample 3')

# sample4_specs = {'Stress (N/mm)' : np.diff(df[specimen_type][fourth_specimen]['Sample 4']['Stress (N/mm)']), 'Strain (mm/mm)': np.diff(df[specimen_type][fourth_specimen]['Sample 4']['Strain (mm/mm)'])} 
# a = pd.DataFrame(data=sample4_specs)
# a = a[a[:] > -0.1].dropna()
# b = a.index
# df_2_4 = (df.truncate(after = b[-1]-6)).copy()
# #bad run 
# plt.plot(df_2_4[specimen_type][fourth_specimen]['Sample 4']['Strain (mm/mm)'], df_2_4[specimen_type][fourth_specimen]['Sample 4']['Stress (N/mm)'], color = 'lime', marker = 'o', markersize = 2, label = fourth_specimen + ' Sample 4')

# sample5_specs = {'Stress (N/mm)' : np.diff(df[specimen_type][fourth_specimen]['Sample 5']['Stress (N/mm)']), 'Strain (mm/mm)': np.diff(df[specimen_type][fourth_specimen]['Sample 5']['Strain (mm/mm)'])} 
# a = pd.DataFrame(data=sample5_specs)
# a = a[a[:] > -0.1].dropna()
# b = a.index
# df_2_5 = (df.truncate(after = b[-1]+2)).copy()
# #bad run (broke in the grip)
# plt.plot(df_2_5[specimen_type][fourth_specimen]['Sample 5']['Strain (mm/mm)'], df_2_5[specimen_type][fourth_specimen]['Sample 5']['Stress (N/mm)'], color = 'blue', marker = 'o', markersize = 2, label = fourth_specimen + ' Sample 5')

# sample6_specs = {'Stress (N/mm)' : np.diff(df[specimen_type][fourth_specimen]['Sample 6']['Stress (N/mm)']), 'Strain (mm/mm)': np.diff(df[specimen_type][fourth_specimen]['Sample 6']['Strain (mm/mm)'])} 
# a = pd.DataFrame(data=sample6_specs)
# a = a[a[:] > -0.1].dropna()
# b = a.index
# df_2_6 = (df.truncate(after = b[-1]-4)).copy()
# #bad run (broke in the grip)
# plt.plot(df_2_6[specimen_type][fourth_specimen]['Sample 6']['Strain (mm/mm)'], df_2_6[specimen_type][fourth_specimen]['Sample 6']['Stress (N/mm)'], color = 'purple', marker = 'o', markersize = 2, label = third_specimen +' Sample 6')



plt.title(specimen_type + ' : ' + fourth_specimen  + ' (cleaned)')
plt.ylabel('Stress (MPa)')
plt.xlabel('Strain (mm/mm)')
plt.legend(loc=10, bbox_to_anchor=(1.3,0.5))
plt.savefig(r'E:\National Research Council of Canada\YadienkaCNTResults\new_plots\K28B-26\cummulative_stress_v_strain_clean.png', dpi = 300,  bbox_inches ='tight')
plt.show()

# %% [markdown]
# # Comparison Bar Charts

# %%
df = pd.read_csv(r"D:\National Research Council of Canada\YadienkaCNTResults\april_09_2021\APRIL12\all_data\iti_confusion_mat.csv", header=[0,1])
df
# Out:
#   Unnamed: 0_level_0     Modulus Yield Stress (MPa) Yield Strain (mm/mm)  \
#   Unnamed: 0_level_1     Sample1            Sample1              Sample1
# 0        ITI-4060-S1   99.415837           0.467107             0.005353
# 1        ITI-4060-S2  292.568374           1.107072             0.005200
#
#   Ultimate Stress (MPa) Strain (mm/mm) at Ultimate Stress  \
#                 Sample1                           Sample1
# 0              7.381020                          0.491199
# 1             11.704547                          0.546698
#
#   Failure Stress (MPa) Failure Strain (mm/mm) Energy--Ut--(J/m^3)     Modulus  \
#                Sample1                Sample1             Sample1     Sample2
# 0             7.218784               0.465869            2.143531   93.932574
# 1            11.592243               0.549316            4.057901  259.998804
#
#    ... Failure Strain (mm/mm) Energy--Ut--(J/m^3)     Modulus  \
# ...

# %% [markdown]
# ## Average and STD error dataframe

# %% [markdown]
# ### NANONB-3

# %%
confusion_mat_avgs_ITI_1 = pd.DataFrame()

# %%
confusion_mat_avgs_ITI_1['Modulus'] = [np.average(df.loc[0]['Modulus'][['Sample1', 'Sample2', 'Sample3', 'Sample4', 'Sample5', 'Sample6']])]

confusion_mat_avgs_ITI_1['Yield Stress (MPa)'] = [(np.average(df.loc[0]['Yield Stress (MPa)'][['Sample1', 'Sample2', 'Sample3', 'Sample4', 'Sample5', 'Sample6']]))]

confusion_mat_avgs_ITI_1['Yield Strain (mm/mm)'] = [(np.average(df.loc[0]['Yield Strain (mm/mm)'][['Sample1', 'Sample2', 'Sample3', 'Sample4', 'Sample5', 'Sample6']]))]

confusion_mat_avgs_ITI_1['Ultimate Stress (MPa)'] = [np.average(df.loc[0]['Ultimate Stress (MPa)'][['Sample1', 'Sample2', 'Sample3', 'Sample4', 'Sample5', 'Sample6']])]

confusion_mat_avgs_ITI_1['Strain @ Ult Stress (mm/mm)'] = [np.average(df.loc[0]['Strain (mm/mm) at Ultimate Stress'][['Sample1', 'Sample2', 'Sample3', 'Sample4', 'Sample5', 'Sample6']])]

confusion_mat_avgs_ITI_1['Failure Stress (MPa)'] = [np.average(df.loc[0]['Failure Stress (MPa)'][['Sample1', 'Sample2', 'Sample3', 'Sample4', 'Sample5', 'Sample6']])]

confusion_mat_avgs_ITI_1['Failure Strain (mm/mm)'] = [np.average(df.loc[0]['Failure Strain (mm/mm)'][['Sample1', 'Sample2', 'Sample3', 'Sample4', 'Sample5', 'Sample6']])]

confusion_mat_avgs_ITI_1['Energy--Ut--(J/m^3)'] = [np.average(df.loc[0]['Energy--Ut--(J/m^3)'][['Sample1', 'Sample2', 'Sample3', 'Sample4', 'Sample5', 'Sample6']])]

confusion_mat_avgs_ITI_1
# Out:
#       Modulus  Yield Stress (MPa)  Yield Strain (mm/mm)  \
# 0  117.198931            0.507023              0.005256
#
#    Ultimate Stress (MPa)  Strain @ Ult Stress (mm/mm)  Failure Stress (MPa)  \
# 0                7.35321                     0.441106              7.187471
#
#    Failure Strain (mm/mm)  Energy--Ut--(J/m^3)
# 0                0.427339             1.939371

# %%
confusion_mat_std_ITI_1 = pd.DataFrame()

# %%
confusion_mat_std_ITI_1['Modulus Std'] = [np.std(df.loc[0]['Modulus'][['Sample1', 'Sample2', 'Sample3', 'Sample4', 'Sample5', 'Sample6']])]

confusion_mat_std_ITI_1['Yield Stress (MPa) Std'] = [(np.std(df.loc[0]['Yield Stress (MPa)'][['Sample1', 'Sample2', 'Sample3', 'Sample4', 'Sample5', 'Sample6']]))]

confusion_mat_std_ITI_1['Yield Strain (mm/mm) Std'] = [(np.std(df.loc[0]['Yield Strain (mm/mm)'][['Sample1', 'Sample2', 'Sample3', 'Sample4', 'Sample5', 'Sample6']]))]

confusion_mat_std_ITI_1['Ultimate Stress (MPa) Std'] = [np.std(df.loc[0]['Ultimate Stress (MPa)'][['Sample1', 'Sample2', 'Sample3', 'Sample4', 'Sample5', 'Sample6']])]

confusion_mat_std_ITI_1['Strain @ Ult Stress (mm/mm) Std'] = [np.std(df.loc[0]['Strain (mm/mm) at Ultimate Stress'][['Sample1', 'Sample2', 'Sample3', 'Sample4', 'Sample5', 'Sample6']])]

confusion_mat_std_ITI_1['Failure Stress (MPa) Std'] = [np.std(df.loc[0]['Failure Stress (MPa)'][['Sample1', 'Sample2', 'Sample3', 'Sample4', 'Sample5', 'Sample6',]])]

confusion_mat_std_ITI_1['Failure Strain (mm/mm) Std'] = [np.std(df.loc[0]['Failure Strain (mm/mm)'][['Sample1', 'Sample2', 'Sample3', 'Sample4', 'Sample5', 'Sample6']])]

confusion_mat_std_ITI_1['Energy--Ut--(J/m^3) Std'] = [np.std(df.loc[0]['Energy--Ut--(J/m^3)'][['Sample1', 'Sample2', 'Sample3', 'Sample4', 'Sample5', 'Sample6']])]
confusion_mat_std_ITI_1
# Out:
#    Modulus Std  Yield Stress (MPa) Std  Yield Strain (mm/mm) Std  \
# 0    25.300474                0.062035                  0.000104
#
#    Ultimate Stress (MPa) Std  Strain @ Ult Stress (mm/mm) Std  \
# 0                   0.793711                          0.02885
#
#    Failure Stress (MPa) Std  Failure Strain (mm/mm) Std  \
# 0                  0.781205                    0.025809
#
#    Energy--Ut--(J/m^3) Std
# 0                 0.327894

# %% [markdown]
# ### NANONB-4

# %%
confusion_mat_avgs_ITI_2 = pd.DataFrame()

# %%
confusion_mat_avgs_ITI_2['Modulus'] = [np.average(df.loc[1]['Modulus'][['Sample1', 'Sample3', 'Sample4', 'Sample5', 'Sample6']])]

confusion_mat_avgs_ITI_2['Yield Stress (MPa)'] = [(np.average(df.loc[1]['Yield Stress (MPa)'][['Sample1', 'Sample3', 'Sample4', 'Sample5', 'Sample6']]))]

confusion_mat_avgs_ITI_2['Yield Strain (mm/mm)'] = [(np.average(df.loc[1]['Yield Strain (mm/mm)'][['Sample1', 'Sample3', 'Sample4', 'Sample5', 'Sample6']]))]

confusion_mat_avgs_ITI_2['Ultimate Stress (MPa)'] = [np.average(df.loc[1]['Ultimate Stress (MPa)'][['Sample1', 'Sample3', 'Sample4', 'Sample5', 'Sample6']])]

confusion_mat_avgs_ITI_2['Strain @ Ult Stress (mm/mm)'] = [np.average(df.loc[1]['Strain (mm/mm) at Ultimate Stress'][['Sample1', 'Sample3', 'Sample4', 'Sample5', 'Sample6']])]

confusion_mat_avgs_ITI_2['Failure Stress (MPa)'] = [np.average(df.loc[1]['Failure Stress (MPa)'][['Sample1', 'Sample3', 'Sample4', 'Sample5', 'Sample6']])]

confusion_mat_avgs_ITI_2['Failure Strain (mm/mm)'] = [np.average(df.loc[1]['Failure Strain (mm/mm)'][['Sample1', 'Sample3', 'Sample4', 'Sample5', 'Sample6']])]

confusion_mat_avgs_ITI_2['Energy--Ut--(J/m^3)'] = [np.average(df.loc[1]['Energy--Ut--(J/m^3)'][['Sample1', 'Sample3', 'Sample4', 'Sample5', 'Sample6']])]

confusion_mat_avgs_ITI_2
# Out:
#       Modulus  Yield Stress (MPa)  Yield Strain (mm/mm)  \
# 0  287.062736            1.111461              0.005171
#
#    Ultimate Stress (MPa)  Strain @ Ult Stress (mm/mm)  Failure Stress (MPa)  \
# 0              13.513835                     0.647139             12.453514
#
#    Failure Strain (mm/mm)  Energy--Ut--(J/m^3)
# 0                0.565358             5.621794

# %%
confusion_mat_std_ITI_2 = pd.DataFrame()

# %%
confusion_mat_std_ITI_2['Modulus Std'] = [np.std(df.loc[1]['Modulus'][['Sample1', 'Sample3', 'Sample4', 'Sample5', 'Sample6']])]

confusion_mat_std_ITI_2['Yield Stress (MPa) Std'] = [(np.std(df.loc[1]['Yield Stress (MPa)'][['Sample1', 'Sample3', 'Sample4', 'Sample5', 'Sample6']]))]

confusion_mat_std_ITI_2['Yield Strain (mm/mm) Std'] = [(np.std(df.loc[1]['Yield Strain (mm/mm)'][['Sample1', 'Sample3', 'Sample4', 'Sample5', 'Sample6']]))]

confusion_mat_std_ITI_2['Ultimate Stress (MPa) Std'] = [np.std(df.loc[1]['Ultimate Stress (MPa)'][['Sample1', 'Sample3', 'Sample4', 'Sample5', 'Sample6']])]

confusion_mat_std_ITI_2['Strain @ Ult Stress (mm/mm) Std'] = [np.std(df.loc[1]['Strain (mm/mm) at Ultimate Stress'][['Sample1', 'Sample3', 'Sample4', 'Sample5', 'Sample6']])]

confusion_mat_std_ITI_2['Failure Stress (MPa) Std'] = [np.std(df.loc[1]['Failure Stress (MPa)'][['Sample1', 'Sample3', 'Sample4', 'Sample5', 'Sample6']])]

confusion_mat_std_ITI_2['Failure Strain (mm/mm) Std'] = [np.std(df.loc[1]['Failure Strain (mm/mm)'][['Sample1', 'Sample3', 'Sample4', 'Sample5', 'Sample6']])]

confusion_mat_std_ITI_2['Energy--Ut--(J/m^3) Std'] = [np.std(df.loc[1]['Energy--Ut--(J/m^3)'][['Sample1', 'Sample3', 'Sample4', 'Sample5', 'Sample6']])]

confusion_mat_std_ITI_2
# Out:
#    Modulus Std  Yield Stress (MPa) Std  Yield Strain (mm/mm) Std  \
# 0    20.608549                0.108274                   0.00002
#
#    Ultimate Stress (MPa) Std  Strain @ Ult Stress (mm/mm) Std  \
# 0                   1.424313                          0.06331
#
#    Failure Stress (MPa) Std  Failure Strain (mm/mm) Std  \
# 0                  0.843196                     0.05606
#
#    Energy--Ut--(J/m^3) Std
# 0                 1.069414

# %% [markdown]
# # Modulus Comparison

# %% [markdown]
# ## You need to merge all the dataframes in order to graph them nicely

# %% [markdown]
# ### Merge Avg and Std Dataframe

# %%
cum_avg_confusion_mat = pd.concat((confusion_mat_avgs_ITI_1, confusion_mat_avgs_ITI_2), axis=0)
cum_stds_confusion_mat = pd.concat((confusion_mat_std_ITI_1, confusion_mat_std_ITI_2),axis=0)

cum_avg_confusion_mat.to_csv(r'D:\National Research Council of Canada\YadienkaCNTResults\april_09_2021\APRIL12\all_data\avg_confusion_mat.csv')
cum_stds_confusion_mat.to_csv(r'D:\National Research Council of Canada\YadienkaCNTResults\april_09_2021\APRIL12\all_data\std_confusion_mat.csv')

# %% [markdown]
# # Modulus Plot

# %%
cum_stds_confusion_mat
# Out:
#    Modulus Std  Yield Stress (MPa) Std  Yield Strain (mm/mm) Std  \
# 0    25.300474                0.062035                  0.000104
# 0    20.608549                0.108274                  0.000020
#
#    Ultimate Stress (MPa) Std  Strain @ Ult Stress (mm/mm) Std  \
# 0                   0.793711                          0.02885
# 0                   1.424313                          0.06331
#
#    Failure Stress (MPa) Std  Failure Strain (mm/mm) Std  \
# 0                  0.781205                    0.025809
# 0                  0.843196                    0.056060
#
#    Energy--Ut--(J/m^3) Std
# 0                 0.327894
# 0                 1.069414

# %%
cum_avg_confusion_mat['Modulus'].plot.bar(align='center', rot=0, yerr=cum_stds_confusion_mat['Modulus Std'], capsize=5)

plt.title('Tensile Modulus')
plt.ylabel('Modulus (MPa)')
plt.xlabel('ITI-4060-S1' + '                                ' + 'ITI-4060-S2')
plt.savefig(r'D:\National Research Council of Canada\YadienkaCNTResults\april_09_2021\APRIL12\all_data\moduli_comparison.png', bbox_inches='tight', dpi = 300)
plt.show()

# %% [markdown]
# # Yield Stress

# %%
cum_avg_confusion_mat['Yield Stress (MPa)'].plot.bar(align='center', rot=0, yerr=cum_stds_confusion_mat['Yield Stress (MPa) Std'], capsize=5)

plt.title('Yield Stress')
plt.ylabel('Stress (MPa)')
plt.xlabel('ITI-4060-S1' + '                                ' + 'ITI-4060-S2')
plt.savefig(r'D:\National Research Council of Canada\YadienkaCNTResults\april_09_2021\APRIL12\all_data\yield_stress.png', bbox_inches='tight', dpi = 300)
plt.show()

# %% [markdown]
# # Yield Strain

# %%
cum_avg_confusion_mat['Yield Strain (mm/mm)'].plot.bar(align='center', rot=0, yerr=cum_stds_confusion_mat['Yield Strain (mm/mm) Std'], capsize=5)

plt.title('Yield Strain')
plt.ylabel('Strain (mm/mm)')
plt.xlabel('ITI-4060-S1' + '                                ' + 'ITI-4060-S2')
plt.savefig(r'D:\National Research Council of Canada\YadienkaCNTResults\april_09_2021\APRIL12\all_data\yield_strain.png', bbox_inches='tight', dpi = 300)
plt.show()

# %% [markdown]
# # Ultimate Stress

# %%
cum_avg_confusion_mat['Ultimate Stress (MPa)'].plot.bar(align='center', rot=0, yerr=cum_stds_confusion_mat['Ultimate Stress (MPa) Std'], capsize=5)

plt.title('Ultimate Stress')
plt.ylabel('Stress (MPa)')
plt.xlabel('ITI-4060-S1' + '                                ' + 'ITI-4060-S2')
plt.savefig(r'D:\National Research Council of Canada\YadienkaCNTResults\april_09_2021\APRIL12\all_data\ultimate_stress.png', bbox_inches='tight', dpi = 300)
plt.show()

# %% [markdown]
# # Strain @ Ult Stress (mm/mm)

# %%
cum_avg_confusion_mat['Strain @ Ult Stress (mm/mm)'].plot.bar(align='center', rot=0, yerr=cum_stds_confusion_mat['Strain @ Ult Stress (mm/mm) Std'], capsize=5)

plt.title('Strain at Ultimate Tensile Stress')
plt.ylabel('Strain (mm/mm)')
plt.xlabel('ITI-4060-S1' + '                                ' + 'ITI-4060-S2')
plt.savefig(r'D:\National Research Council of Canada\YadienkaCNTResults\april_09_2021\APRIL12\all_data\strain_at_ultimate_stress.png', bbox_inches='tight', dpi = 300)
plt.show()

# %% [markdown]
# # Failure Stress (MPa)

# %%
cum_avg_confusion_mat['Failure Stress (MPa)'].plot.bar(align='center', rot=0, yerr=cum_stds_confusion_mat['Failure Stress (MPa) Std'], capsize=5)

plt.title('Failure Stress')
plt.ylabel('Stress (MPa)')
plt.xlabel('ITI-4060-S1' + '                                ' + 'ITI-4060-S2')
plt.savefig(r'D:\National Research Council of Canada\YadienkaCNTResults\april_09_2021\APRIL12\all_data\failure_stress.png', bbox_inches='tight', dpi = 300)
plt.show()

# %% [markdown]
# # Failure Strain (mm/mm)

# %%
cum_avg_confusion_mat['Failure Strain (mm/mm)'].plot.bar(align='center', rot=0, yerr=cum_stds_confusion_mat['Failure Strain (mm/mm) Std'], capsize=5)

plt.title('Failure Strain')
plt.xlabel('ITI-4060-S1' + '                                ' + 'ITI-4060-S2')
plt.savefig(r'D:\National Research Council of Canada\YadienkaCNTResults\april_09_2021\APRIL12\all_data\failure_strain.png', bbox_inches='tight', dpi = 300)
plt.show()

# %% [markdown]
# # Energy--Ut--(J/m^3) Std

# %%
cum_avg_confusion_mat['Energy--Ut--(J/m^3)'].plot.bar(align='center', rot=0, yerr=cum_stds_confusion_mat['Energy--Ut--(J/m^3) Std'], capsize=5)

plt.title('Energy')
plt.ylabel('Energy (MJ/m^3)')
plt.xlabel('ITI-4060-S1' + '                                ' + 'ITI-4060-S2')
plt.savefig(r'D:\National Research Council of Canada\YadienkaCNTResults\april_09_2021\APRIL12\all_data\energy.png', bbox_inches='tight', dpi = 300)
plt.show()
